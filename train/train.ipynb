# %%
def hello(): 
    print('Hello, World!')
hello()

# %%
EXPECTED_BAKE_TIME = 40
print(EXPECTED_BAKE_TIME)

# %%
def bake_time_remaining(bake_time_passed):    
    """Calculate the bake time remaining.

    :param elapsed_bake_time: int - baking time already elapsed.
    :return: int - remaining bake time (in minutes) derived from 'EXPECTED_BAKE_TIME'.

    Function that takes the actual minutes the lasagna has been in the oven as
    an argument and returns how many minutes the lasagna still needs to bake
    based on the `EXPECTED_BAKE_TIME`.
    """

    return EXPECTED_BAKE_TIME - bake_time_passed

# %%
bake_time_remaining(30)

# %%
def preparation_time_in_minutes(number_of_layers):
    return number_of_layers * 2

# %%
preparation_time_in_minutes(2)

# %%
EXPECTED_BAKE_TIME = 40
PREPARATION_TIME = 2

#TODO: Remove 'pass' and complete the 'bake_time_remaining()' function below.
def bake_time_remaining(elapsed_bake_time):    
    return EXPECTED_BAKE_TIME - elapsed_bake_time


#TODO: Define the 'preparation_time_in_minutes()' function below.
# To avoid the use of magic numbers (see: https://en.wikipedia.org/wiki/Magic_number_(programming)), you should define a PREPARATION_TIME constant.
# You can do that on the line below the 'EXPECTED_BAKE_TIME' constant.
# This will make it easier to do calculations, and make changes to your code.

def preparation_time_in_minutes(number_of_layers):
    return number_of_layers * PREPARATION_TIME


#TODO: define the 'elapsed_time_in_minutes()' function below.

def elapsed_time_in_minutes(number_of_layers, elapsed_bake_time):
    return number_of_layers * PREPARATION_TIME + elapsed_bake_time

# %%
bake_time_remaining(30)

# %%
preparation_time_in_minutes(2)

# %%
elapsed_time_in_minutes(3, 20)

# %%
293 + 20 + 57 + 48 + 1 + 49 + 91 + 92

# %%
def exchangeable_value(budget, exchange_rate, spread, denomination):
    """

    :param budget: float - the amount of your money you are planning to exchange.
    :param exchange_rate: float - the unit value of the foreign currency.
    :param spread: int - percentage that is taken as an exchange fee.
    :param denomination: int - the value of a single bill.
    :return: int - maximum value you can get.
    """

    return  (budget / (exchange_rate + (exchange_rate*(spread/100))) // denomination) * denomination

# %%
exchangeable_value(127.25, 1.20, 10, 20)

# %%
exchangeable_value(127.25, 1.20, 10, 5)

# %%
def get_change(budget, exchanging_value):
    """

    :param budget: float - amount of money you own.
    :param exchanging_value: float - amount of your money you want to exchange now.
    :return: float - amount left of your starting currency after exchanging.
    """

    return float(budget % exchanging_value)

# %%
get_change(127.5, 120)

# %%
def square(number):
    return 2**number

# %%
square(4)

# %%
def square(number):
    return 2 ** (number - 1)


def total(number):
    return (2**number)-1

# %%
square(4)

# %%
total(3)

# %%
def square(number):
    if number <= 0 or number >= 65:
        raise ValueError("square must be between 1 and 64")
    return 2 ** (number - 1)

# %%
square(64)

# %%
def eat_ghost(power_pellet_active, touching_ghost):
    """Verify that Pac-Man can eat a ghost if he is empowered by a power pellet.

    :param power_pellet_active: bool - does the player have an active power pellet?
    :param touching_ghost: bool - is the player touching a ghost?
    :return: bool - can a ghost be eaten?
    """

    return power_pellet_active and touching_ghost

# %%
eat_ghost(False, True)

# %%
def score(touching_power_pellet, touching_dot):
    """Verify that Pac-Man has scored when a power pellet or dot has been eaten.

    :param touching_power_pellet: bool - is the player touching a power pellet?
    :param touching_dot: bool - is the player touching a dot?
    :return: bool - has the player scored or not?
    """

    return touching_power_pellet or touching_dot

# %%
score(True, False)

# %%
def lose(power_pellet_active, touching_ghost):
    """Trigger the game loop to end (GAME OVER) when Pac-Man touches a ghost without his power pellet.

    :param power_pellet_active: bool - does the player have an active power pellet?
    :param touching_ghost: bool - is the player touching a ghost?
    :return: bool - has the player lost the game?
    """

    return touching_ghost and not power_pellet_active

# %%
lose(False, False)

# %%
def win(has_eaten_all_dots, power_pellet_active, touching_ghost):
    """Trigger the victory event when all dots have been eaten.

    :param has_eaten_all_dots: bool - has the player "eaten" all the dots?
    :param power_pellet_active: bool - does the player have an active power pellet?
    :param touching_ghost: bool - is the player touching a ghost?
    :return: bool - has the player won the game?
    """

    return has_eaten_all_dots and power_pellet_active and touching_ghost

# %%
win(True, False, False)

# %%
def is_armstrong(number):
    digits = str(number)
    power = len(digits)

    total = sum(int(digit) ** power for digit in digits)

    return total == number

# %%
str(250)

# %%
for lettre in "chat":
    print(lettre)

# %%
nombre = 123
nbrcarac = str(nombre)
len(nbrcarac)

# %%
digits = "153"

for digit in digits:
    print(int(digit) * 3)

# %%
3%2

# %%
x = 2
paire = (x%2 == 0)
paire

# %%
def steps(number):
    if number <= 0:
        raise ValueError("Le nombre doit être un entier positif")
    paire = (number%2 == 0)

    if paire == True:
        print("Paire")
    else:
        print("Impaire")
    
    return

# %%
steps(3)

# %%
def steps(number):
    if number <= 0:
        raise ValueError("Le nombre doit être un entier positif")
    paire = (number%2 == 0)

    for x in paire:
        if paire == True:
            division = number/2
        else:
            multiplication = number*3+1
    return

# %%
def steps(number):
    if number <= 0.999 or type(number) != int:
        raise ValueError("Le nombre doit être un entier positif")
    etape = 0

    while number > 1:
        etape = etape+1
        paire = (number%2 == 0)
        if paire:
            number = number // 2
        else:
            number = (number*3)+1
        
    return etape

# %%
steps(1)

# %%
type(1) == int

# %%
def leap_year(year):
    bisextile = year%4 == 0 and not year%100 == 0
    return year%400 == 0 or year%4 == 0 and not year%100 == 0

# %%
leap_year(2000)

# %%
year = 2000
year%4 == 0 and not year%100 == 0

# %%
def equilateral(sides):
    un = sides[0]
    deux = sides[1]
    trois = sides[2]

    
    return un == deux == trois

# %%
equilateral([1,1,1])

# %%
def equilateral(sides):
    return

# %%
equilateral([5,8,1])

# %%
def isosceles(sides):
    un = sides[0]
    deux = sides[1]
    trois = sides[2]

    
    return un == deux or deux == trois or un == trois
    pass

# %%
isosceles([8,5,5])

# %%
def scalene(sides):
    un = sides[0]
    deux = sides[1]
    trois = sides[2]
    return not un == deux and not deux == trois and not un == trois

# %%
scalene([1,2,3])

# %%
def _valid_triangle(sides):
    """Vérifie si les trois côtés forment un triangle valide (non dégénéré)."""
    if len(sides) != 3:
        return False
    a, b, c = sorted(sides)
    return a > 0 and b > 0 and c > 0 and a + b > c


def equilateral(sides):
    if not _valid_triangle(sides):
        return False
    a, b, c = sorted(sides)
    return a == b == c


def isosceles(sides):
    if not _valid_triangle(sides):
        return False
    a, b, c = sorted(sides)
    return a == b or b == c or a == c  # inclut l'équilatéral


def scalene(sides):
    if not _valid_triangle(sides):
        return False
    a, b, c = sorted(sides)
    return a < b < c

# %%
isosceles([8,5,5])

# %%
def reactor_efficiency(voltage, current, theoretical_max_power):
    """Assess reactor efficiency zone.

    :param voltage: int or float - voltage value.
    :param current: int or float - current value.
    :param theoretical_max_power: int or float - power that corresponds to a 100% efficiency.
    :return: str - one of ('green', 'orange', 'red', or 'black').

    Efficiency can be grouped into 4 bands:

    1. green -> efficiency of 80% or more,
    2. orange -> efficiency of less than 80% but at least 60%,
    3. red -> efficiency below 60%, but still 30% or more,
    4. black ->  less than 30% efficient.

    The percentage value is calculated as
    (generated power/ theoretical max power)*100
    where generated power = voltage * current
    """

    generated_power = voltage * current
    pourcent_generated = (generated_power/ theoretical_max_power) * 100

    if pourcent_generated >= 80:
        color = "green"
    elif pourcent_generated >= 60:
        color = "orange"
    elif pourcent_generated >= 30:
        color = "red"
    else :
        color = "black"
    return color

# %%
reactor_efficiency(200,50,15000)

# %%
def is_criticality_balanced(temperature, neutrons_emitted):
    """Verify criticality is balanced.

    :param temperature: int or float - temperature value in kelvin.
    :param neutrons_emitted: int or float - number of neutrons emitted per second.
    :return: bool - is criticality balanced?

    A reactor is said to be balanced in criticality if it satisfies the following conditions:
        - The temperature is less than 800 K.
        - The number of neutrons emitted per second is greater than 500.
        - The product of temperature and neutrons emitted per second is less than 500000.
    """
    return (
        temperature < 800
        and neutrons_emitted > 500
        and temperature * neutrons_emitted < 500000
    )

# %%
is_criticality_balanced(750, 600)

# %%
def fail_safe(temperature, neutrons_produced_per_second, threshold):
    """Assess and return status code for the reactor.

    :param temperature: int or float - value of the temperature in kelvin.
    :param neutrons_produced_per_second: int or float - neutron flux.
    :param threshold: int or float - threshold for category.
    :return: str - one of ('LOW', 'NORMAL', 'DANGER').

    1. 'LOW' -> `temperature * neutrons per second` < 90% of `threshold`
    2. 'NORMAL' -> `temperature * neutrons per second` +/- 10% of `threshold`
    3. 'DANGER' -> `temperature * neutrons per second` is not in the above-stated ranges
    """
    if temperature * neutrons_produced_per_second < threshold * 0.9 :
        state = "LOW"
    elif temperature * neutrons_produced_per_second >= threshold * 0.9 and temperature * neutrons_produced_per_second <= threshold * 1.1 :
        state = "NORMAL"    
    else :
        state = "DANGER"
    

    return state

# %%
fail_safe(temperature=1000, neutrons_produced_per_second=30, threshold=5000)

# %%
"AAAA ?".isupper()

# %%
def response(hey_bob):
    if hey_bob.isupper() == True and hey_bob.rstrip().endswith("?"):
        rep = "Calm down, I know what I'm doing!"
    elif hey_bob.rstrip().endswith("?"):
        rep = "Sure."
    elif hey_bob.isupper() == True:
        rep = "Whoa, chill out!"
    elif len(hey_bob) == 0 or hey_bob.isspace() == True:
        rep = "Fine. Be that way!"
    else:
        rep = "Whatever."

    return rep

# %%
response("Okay if like my  spacebar  quite a bit?   ")

# %%
def convert(number):
    bruit = ""
    if number % 3 == 0:
        bruit = "Pling"
        if number % 5 == 0:
            bruit = bruit + "Plang"
            if number % 7 == 0:
                bruit = bruit + "Plong" 
        elif number % 7 == 0:
            bruit = bruit + "Plong"






            
    return bruit

# %%
convert(105)

# %%
def convert(number):
    bruit = ""

    if number % 3 == 0:
        bruit = "Pling"
        if number % 5 == 0:
            bruit += "Plang"
            if number % 7 == 0:
                bruit += "Plong"
        elif number % 7 == 0:
            bruit += "Plong"

    elif number % 5 == 0:
        bruit = "Plang"
        if number % 7 == 0:
            bruit += "Plong"

    elif number % 7 == 0:
        bruit = "Plong"

    else:
        bruit = str(number)

    return bruit

# %%
convert(105)

# %%
#version plus propre les if s'éxcute tous, pas les elif qui s'arrête à la première condition

def convert(number):
    bruit = ""
    if number % 3 == 0:
        bruit += "Pling"
    if number % 5 == 0:
        bruit += "Plang"
    if number % 7 == 0:
        bruit += "Plong"
    
    if not bruit:                  # si aucun son n'a été ajouté
        bruit = str(number)
    
    return bruit

# %%
def translate(text):
    ajout = ""
    if text and (text[0] == "a" or text[0] == "e" or text[0] == "i" or 
                 text[0] == "o" or text[0] == "u"):
        ajout = "ay"
        text = text + ajout
    if text and (text[0:1] == "xr" or text[0:1] == "yt":
        ajout = "ay"
        text = text + ajout
    
    return text

# %%
translate("axx")

# %%
def translate(phrase):
    """
    Traduit une phrase entière en Pig Latin.
    - Sépare la phrase en mots
    - Traduit chaque mot individuellement selon les règles 1 à 4
    - Recompose la phrase avec des espaces
    - Préserve la majuscule initiale de chaque mot si elle existe
    """
    if not phrase:
        return phrase

    # Séparation en mots (gère les espaces multiples automatiquement)
    words = phrase.split()

    translated_words = []

    for original_word in words:
        if not original_word:
            translated_words.append(original_word)
            continue

        # On travaille en minuscules pour toutes les décisions
        word = original_word.lower()

        vowels = 'aeiou'

        # Règle 1 : commence par voyelle OU "xr" OU "yt"
        if word[0] in vowels or word.startswith('xr') or word.startswith('yt'):
            pig = word + 'ay'

        # Sinon : règles 2, 3 et 4 – recherche du début de la partie « voyelle »
        else:
            i = 0
            index = len(word)  # si aucune voyelle/y trouvée

            while i < len(word):
                char = word[i]

                # Règle 3 : "qu" – le "u" après "q" reste dans les consonnes
                if char == 'u' and i > 0 and word[i - 1] == 'q':
                    i += 1
                    continue

                # Voyelle standard → on s'arrête
                if char in vowels:
                    index = i
                    break

                # Règle 4 : "y" après au moins une consonne → traité comme voyelle
                if char == 'y' and i > 0:
                    index = i
                    break

                i += 1

            # Construction : partie voyelle + consonnes déplacées + "ay"
            pig = word[index:] + word[:index] + 'ay'

        # Application de la casse : on utilise la version tout en minuscules,
        # puis on remet une majuscule au début si le mot original en avait une
        if original_word and original_word[0].isupper():
            pig = pig.capitalize()  # met la première lettre en majuscule et le reste en minuscule

        translated_words.append(pig)

    # Recomposition de la phrase
    return ' '.join(translated_words)

# %%
translate("yaquaaa")

# %%
"5" is not None
# Out:
# <>:1: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# /tmp/ipykernel_29929/2893210617.py:1: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   "5" is not None
# True

# %%
id(4)
# Out:
# 11755784

# %%
def value_of_card(card):
    if card == "A":
        value = 1
    elif card == "K" or card == "Q" or card == "J":
        value = 10
    else:
        value = card
    return value

# %%
value_of_card("2")
# Out:
# '2'

# %%
def higher_card(card_one, card_two):

# %%
higher_card("K", "9")
# Out:
# 'K'

# %%
def value_of_ace(card_one, card_two):
    value_one = int(value_of_card(card_one))
    value_two = int(value_of_card(card_two))
    total_no_ace = value_one + value_two
    value_ace = 0

    if "A" in (card_one, card_two):
        total_no_ace = total_no_ace + 10

    if total_no_ace <= 10:
        value_ace = 11
    else:
        value_ace = 1

    return value_ace

# %%
value_of_ace('2', 'A')
# Out:
# 11

# %%
def is_blackjack(card_one, card_two):
    ten_points = {'J', 'Q', 'K', '10'}
    
    if (card_one in ten_points or card_two in ten_points) and (card_one == 'A' or card_two == 'A'):
        return True
    else:
        return False

# %%
is_blackjack('J', 'A')
# Out:
# True

# %%
def can_split_pairs(card_one, card_two):
    return value_of_card(card_one) == value_of_card(card_two)

# %%
can_split_pairs("A", "Q")
# Out:
# False

# %%
def can_double_down(card_one, card_two):
    total = value_of_card(card_one) + value_of_card(card_two)
    if total == 9 or total == 10 or total == 11:
        return True
    else:   
        return False
